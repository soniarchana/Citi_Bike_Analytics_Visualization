# %%
# Setting environment 
import pandas as pd
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
# import math
import datetime as dt

# %%
# Hide warning messages in notebook
import warnings 
warnings.filterwarnings('ignore')

# Loading csv datafile
citi_bike_df1 = pd.read_csv("data/JC-201801-citibike-tripdata.csv")
citi_bike_df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
citi_bike_df2 = pd.read_csv("data/JC-201802-citibike-tripdata.csv")
citi_bike_df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
citi_bike_df3 = pd.read_csv("data/JC-201803-citibike-tripdata.csv")
citi_bike_df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
citi_bike_df4 = pd.read_csv("data/JC-201804-citibike-tripdata.csv")
citi_bike_df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3638       Washington St
# ...

# %%
citi_bike_df5 = pd.read_csv("data/JC-201805-citibike-tripdata.csv")
citi_bike_df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
citi_bike_df6 = pd.read_csv("data/JC-201806-citibike-tripdata.csv")
citi_bike_df6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
citi_bike_df7 = pd.read_csv("data/JC-201807-citibike-tripdata.csv")
citi_bike_df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
citi_bike_df8 = pd.read_csv("data/JC-201808-citibike-tripdata.csv")
citi_bike_df8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
citi_bike_df9 = pd.read_csv("data/JC-201809-citibike-tripdata.csv")
citi_bike_df9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
citi_bike_df10 = pd.read_csv("data/JC-201810-citibike-tripdata.csv")
citi_bike_df10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1           122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2           211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3           342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4          2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
citi_bike_df11 = pd.read_csv("data/JC-201811-citibike-tripdata.csv")
citi_bike_df11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1           278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2           115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3           155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4            82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
citi_bike_df12 = pd.read_csv("data/JC-201812-citibike-tripdata.csv")
citi_bike_df12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           170  2018-12-01 00:03:53.3860  2018-12-01 00:06:43.7160
# 1           172  2018-12-01 00:47:13.7340  2018-12-01 00:50:05.8160
# 2           247  2018-12-01 00:48:57.6960  2018-12-01 00:53:05.6780
# 3           406  2018-12-01 01:33:53.6630  2018-12-01 01:40:39.7480
# 4           354  2018-12-01 06:26:52.5120  2018-12-01 06:32:46.5170
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3214  Essex Light Rail
# ...

# %%
citi_bike_df = pd.concat([citi_bike_df1, citi_bike_df2, citi_bike_df3, citi_bike_df4, citi_bike_df5, citi_bike_df6, citi_bike_df7, citi_bike_df8, citi_bike_df9, citi_bike_df10, citi_bike_df11, citi_bike_df12])
citi_bike_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# 5               613  2018-01-01 22:05:05.8740  2018-01-01 22:15:19.4190
# 6               290  2018-01-02 12:13:51.7940  2018-01-02 12:18:42.1070
# 7               381  2018-01-02 12:50:03.3430  2018-01-02 12:56:24.6440
# 8               318  2018-01-02 13:55:58.2430  2018-01-02 14:01:16.8810
# 9              1852  2018-01-02 16:55:29.6390  2018-01-02 17:26:22.3050
# 10              460  2018-01-02 17:01:50.5860  2018-01-02 17:09:31.4340
# 11              403  2018-01-02 17:05:12.2360  2018-01-02 17:11:55.2630
# ...

# %%
citi_bike_df=citi_bike_df.rename(index=str, \
    columns={"start station id": "start_station_id", "start station name": "start_station_name", \
             "start station longitude": "start_station_longitude",\
             "start station latitude": "start_station_latitude", "end station id": "end_station_id", \
             "end station name": "end_station_name", "end station latitude":"end_station_latitude", \
             "end station longitude": "end_station_longitude", "birth year": "birth_year"})
citi_bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start_station_id start_station_name  start_station_latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start_station_longitude  end_station_id end_station_name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
citi_bike_df.count()
# Out:
# tripduration               353892
# starttime                  353892
# stoptime                   353892
# start_station_id           353892
# start_station_name         353892
# start_station_latitude     353892
# start_station_longitude    353892
# end_station_id             353892
# end_station_name           353892
# end_station_latitude       353892
# end_station_longitude      353892
# bikeid                     353892
# usertype                   353892
# birth_year                 353892
# gender                     353892
# Month_starttime            353892
# dtype: int64

# %%
citi_bike_df.to_csv('data/citi_bike_2018.csv')
print("All monthly data files merged into one 2018 csv file...")
# Out:
# All monthly data files merged into one 2018 csv file...

# %%
citi_bike_df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                           object
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bikeid                              int64
# usertype                           object
# birth_year                          int64
# gender                              int64
# Month_starttime                     int64
# dtype: object

# %%
# Questions:
citi_bike_df.head()
# Out:
#    tripduration               starttime                  stoptime  \
# 0           932 2018-01-01 02:06:17.541  2018-01-01 02:21:50.0270
# 1           550 2018-01-01 12:06:18.039  2018-01-01 12:15:28.4430
# 2           510 2018-01-01 12:06:56.978  2018-01-01 12:15:27.8100
# 3           354 2018-01-01 14:53:10.186  2018-01-01 14:59:05.0960
# 4           250 2018-01-01 17:34:30.192  2018-01-01 17:38:40.9840
#
#    start_station_id start_station_name  start_station_latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start_station_longitude  end_station_id end_station_name  \
# 0               -74.033459            3199     Newport Pkwy
# 1               -74.033459            3199     Newport Pkwy
# ...

# %%
# How many trips have been recorded total during the chosen period?
print("Number of Trips in 2018 = ", citi_bike_df.bikeid.count())  

# 353892
# Out:
# Number of Trips in 2018 =  353892

# %%
print("Number of Trips Less Than 60 Secs in 2018 : ",[citi_bike_df[citi_bike_df.tripduration < 60]] )  

# None of trip in 2018 is less than 60 Secs
# Out:
# Number of Trips Less Than 60 Secs in 2018 :  [Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bikeid, usertype, birth_year, gender, Month_starttime]
# Index: []]

# %%
print("\nGender Value Counts: ", citi_bike_df.gender.value_counts())
# Out:
# Gender Value Counts:  1    257131
# 2     75345
# 0     21416
# Name: gender, dtype: int64

# %%
print("\nUser Types :", citi_bike_df.usertype.value_counts())
# Out:
# User Types : Subscriber    331725
# Customer       22167
# Name: usertype, dtype: int64

# %%
print("\nStart Station Name :", citi_bike_df.usertype.value_counts())
# Out:
# Start Station Name : Subscriber    331725
# Customer       22167
# Name: usertype, dtype: int64

# %%
# How has the proportion of short-term customers and annual subscribers changed?
df_customers = citi_bike_df.groupby('usertype')['usertype'].count().sort_values(ascending=False).reset_index(name='count')
print(df_customers.head())
x= np.array(df_customers[["count"]].values)
print("x=",x)
print("\nThe proportion of Annual Subscribers vs. short-term customers: \n", x*100.0/sum(x))
# Out:
#      usertype   count
# 0  Subscriber  331725
# 1    Customer   22167
# x= [[331725]
#  [ 22167]]
#
# The proportion of Annual Subscribers vs. short-term customers:
#  [[93.73622461]
#  [ 6.26377539]]

# %%
citi_bike_df = citi_bike_df.dropna(how="any")
citi_bike_df.count()
# Out:
# tripduration               353892
# starttime                  353892
# stoptime                   353892
# start_station_id           353892
# start_station_name         353892
# start_station_latitude     353892
# start_station_longitude    353892
# end_station_id             353892
# end_station_name           353892
# end_station_latitude       353892
# end_station_longitude      353892
# bikeid                     353892
# usertype                   353892
# birth_year                 353892
# gender                     353892
# time                       353892
# dtype: int64

# %%
# By what percentage has total ridership grown?   (doing it month on month)

print("Min starttime:",min(citi_bike_df["starttime"]))
print("Max starttime:",max(citi_bike_df["starttime"])) 

citi_bike_df["starttime"] = pd.to_datetime(citi_bike_df["starttime"])
citi_bike_df["Month_starttime"] = citi_bike_df["starttime"].map((lambda x: x.month))

citi_bike_df.Month_starttime.unique()

citi_bike_df.head()
# Out:
# Min starttime: 2018-01-01 00:01:45.814000
# Max starttime: 2018-12-31 23:25:49.609000
#    tripduration               starttime                  stoptime  \
# 0           932 2018-01-01 02:06:17.541  2018-01-01 02:21:50.0270
# 1           550 2018-01-01 12:06:18.039  2018-01-01 12:15:28.4430
# 2           510 2018-01-01 12:06:56.978  2018-01-01 12:15:27.8100
# 3           354 2018-01-01 14:53:10.186  2018-01-01 14:59:05.0960
# 4           250 2018-01-01 17:34:30.192  2018-01-01 17:38:40.9840
#
#    start_station_id start_station_name  start_station_latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start_station_longitude  end_station_id end_station_name  \
# ...

# %%
# By what percentage has total ridership grown?   (doing it month on month)
print (citi_bike_df.groupby(["usertype","Month_starttime"])["tripduration"].count())
# Out:
# usertype    Month_starttime
# Customer    1                    185
#             2                    189
#             3                    436
#             4                   1743
#             5                   2458
#             6                   3187
#             7                   3794
#             8                   3158
#             9                   3524
#             10                  2004
#             11                   898
#             12                   591
# Subscriber  1                  12492
#             2                  14915
#             3                  16673
#             4                  21891
#             5                  31998
#             6                  37750
#             7                  38474
#             8                  41274
#             9                  35498
#             10                 37134
#             11                 24012
#             12                 19614
# ...

# %%
df_per = citi_bike_df.groupby('Month_starttime')['Month_starttime'].count().reset_index(name='count')
df_per.sort_values(by='Month_starttime', ascending=False)

prev = df_per['count'][0]
for x in df_per['count'].tolist():
    print("prev=",prev)
    print("x = ",x)
    perc = (100/prev*x )-100
    print("percentage =", perc)
    prev = x
    y = y + 1
                
df_per
# Out:
# prev= 12677
# x =  12677
# percentage = 0.0
# prev= 12677
# x =  15104
# percentage = 19.144908101285793
# prev= 15104
# x =  17109
# percentage = 13.274629237288124
# prev= 17109
# x =  23634
# percentage = 38.13782219884271
# prev= 23634
# x =  34456
# percentage = 45.789963611745804
# prev= 34456
# x =  40937
# percentage = 18.809496169027156
# prev= 40937
# x =  42268
# percentage = 3.25133742091505
# prev= 42268
# x =  44432
# percentage = 5.119712311914455
# prev= 44432
# x =  39022
# percentage = -12.17590925459129
# prev= 39022
# x =  39138
# percentage = 0.29726820767773177
# prev= 39138
# x =  24910
# percentage = -36.35341611732843
# prev= 24910
# x =  20205
# percentage = -18.88799678843837
#     Month_starttime  count
# 0                 1  12677
# 1                 2  15104
# 2                 3  17109
# 3                 4  23634
# 4                 5  34456
# 5                 6  40937
# 6                 7  42268
# 7                 8  44432
# ...
